# %%
pip install numpy==1.21 pandas pydub ibm_watson numba librosa
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting numpy==1.21
#   Downloading numpy-1.21.0.zip (10.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 4.5 MB/s eta 0:00:00m eta 0:00:0136m0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pandas in /home/mostafa/.local/lib/python3.10/site-packages (1.4.4)
# Requirement already satisfied: pydub in /home/mostafa/.local/lib/python3.10/site-packages (0.25.1)
# Collecting ibm_watson
#   Downloading ibm-watson-6.1.0.tar.gz (373 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 373.5/373.5 KB 6.7 MB/s eta 0:00:007.9 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting numba
#   Downloading numba-0.56.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 5.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting librosa
#   Downloading librosa-0.9.2-py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.3/214.3 KB 1.8 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/mostafa/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: requests<3.0,>=2.0 in /usr/lib/python3/dist-packages (from ibm_watson) (2.25.1)
# Collecting ibm-cloud-sdk-core==3.*,>=3.3.6
#   Downloading ibm_cloud_sdk_core-3.16.0-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.7/83.7 KB 2.0 MB/s eta 0:00:000:00:01
# Collecting websocket-client==1.1.0
#   Using cached websocket_client-1.1.0-py2.py3-none-any.whl (68 kB)
# Collecting requests<3.0,>=2.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 2.7 MB/s eta 0:00:000:00:01
# Requirement already satisfied: urllib3<2.0.0,>=1.26.0 in /usr/lib/python3/dist-packages (from ibm-cloud-sdk-core==3.*,>=3.3.6->ibm_watson) (1.26.5)
# Collecting PyJWT<3.0.0,>=2.4.0
#   Downloading PyJWT-2.5.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: setuptools<60 in /usr/lib/python3/dist-packages (from numba) (59.6.0)
# Collecting llvmlite<0.40,>=0.39.0dev0
#   Downloading llvmlite-0.39.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.6/34.6 MB 2.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: joblib>=0.14 in /home/mostafa/.local/lib/python3.10/site-packages (from librosa) (1.2.0)
# Collecting scikit-learn>=0.19.1
#   Downloading scikit_learn-1.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 4.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting resampy>=0.2.2
#   Downloading resampy-0.4.2-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 9.7 MB/s eta 0:00:000m eta 0:00:010:00:01
# Requirement already satisfied: decorator>=4.0.10 in /usr/lib/python3/dist-packages (from librosa) (4.4.2)
# Collecting soundfile>=0.10.2
#   Using cached SoundFile-0.10.3.post1-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from librosa) (21.3)
# Collecting audioread>=2.1.9
#   Downloading audioread-3.0.0.tar.gz (377 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 KB 2.3 MB/s eta 0:00:00 MB/s eta 0:00:01:01
#   Preparing metadata (setup.py) ... done
# Collecting pooch>=1.0
#   Using cached pooch-1.6.0-py3-none-any.whl (56 kB)
# Requirement already satisfied: scipy>=1.2.0 in /usr/lib/python3/dist-packages (from librosa) (1.8.0)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/lib/python3/dist-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3.0,>=2.0->ibm_watson) (2020.6.20)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/mostafa/.local/lib/python3.10/site-packages (from requests<3.0,>=2.0->ibm_watson) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3.0,>=2.0->ibm_watson) (3.3)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: cffi>=1.0 in /home/mostafa/.local/lib/python3.10/site-packages (from soundfile>=0.10.2->librosa) (1.15.1)
# Requirement already satisfied: pycparser in /home/mostafa/.local/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)
# Building wheels for collected packages: numpy, ibm_watson, audioread
#   Building wheel for numpy (pyproject.toml) ... done
#   Created wheel for numpy: filename=numpy-1.21.0-cp310-cp310-linux_x86_64.whl size=15983617 sha256=ec6d706b8388fba7c9fb0d2043a3ad51055443bd00f8402706ae1dba8d6d63cd
#   Stored in directory: /home/mostafa/.cache/pip/wheels/05/61/d1/ccc2cd557b39e127ad98a392d9558f3c5dda28764b7f54b2f5
#   Building wheel for ibm_watson (pyproject.toml) ... done
#   Created wheel for ibm_watson: filename=ibm_watson-6.1.0-py3-none-any.whl size=370748 sha256=e5a2e4e7b741787ac4faf13eccd1251b9966394495e209bb48fed43e208ecc45
#   Stored in directory: /home/mostafa/.cache/pip/wheels/18/ff/b2/6eab1b86aca7bb7bb3dba74b8fcfd2895549996fda84a854c9
#   Building wheel for audioread (setup.py) ... done
#   Created wheel for audioread: filename=audioread-3.0.0-py3-none-any.whl size=23706 sha256=e06b6e6fc2cd2c52e20b1831708b4089f35f7f9a65928a497c72683152fc9ada
#   Stored in directory: /home/mostafa/.cache/pip/wheels/da/4b/39/c5f6c4ee93b43281dda4dab5ac5f2bdf9d11074d427493cd55
# Successfully built numpy ibm_watson audioread
# Installing collected packages: websocket-client, threadpoolctl, requests, PyJWT, numpy, llvmlite, audioread, soundfile, scikit-learn, pooch, numba, ibm-cloud-sdk-core, resampy, ibm_watson, librosa
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.4.1
#     Uninstalling websocket-client-1.4.1:
#       Successfully uninstalled websocket-client-1.4.1
# Successfully installed PyJWT-2.5.0 audioread-3.0.0 ibm-cloud-sdk-core-3.16.0 ibm_watson-6.1.0 librosa-0.9.2 llvmlite-0.39.1 numba-0.56.2 numpy-1.21.0 pooch-1.6.0 requests-2.28.1 resampy-0.4.2 scikit-learn-1.1.2 soundfile-0.10.3.post1 threadpoolctl-3.1.0 websocket-client-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys, time
import pandas as pd
from os.path import basename, splitext, dirname, join
from random import randint
from pydub import AudioSegment
import json
from ibm_watson import SpeechToTextV1
from ibm_watson.websocket import RecognizeCallback, AudioSource
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# %%
url='https://api.au-syd.speech-to-text.watson.cloud.ibm.com'
api_key=""
authenticator = IAMAuthenticator(apikey=api_key)

# %%
def stt_audio_file_wav(file_path, format='wav', lang='en-AU', enableDiarization=True, model_str='BroadbandModel'):
    speech_to_text = SpeechToTextV1(authenticator=authenticator)
    speech_to_text.set_service_url(service_url=url)
    #flac_file = convert_to_flac(file_path)
    model=''.join([lang,'_',model_str])
    print(model,file_path)
    audio = AudioSegment.from_file(file_path, format=format)
    audio = audio.set_frame_rate(16000)
    #with open(file_path,'rb') as audio_file:
    recognition_job = speech_to_text.create_job(
            audio=audio.raw_data,
            content_type='audio/l16;rate=16000',
            inactivity_timeout=-1,
            model=model,
            speaker_labels=enableDiarization).get_result()
    job_id = recognition_job['id']
    while True:
        status = speech_to_text.check_job(job_id).get_result()
        if status['status'] in ['completed','failed']:
            break
        print("Not ready yet...")
        time.sleep(10)
    result = status['results'] if status['status']=='completed' else status['details'][0]['error']
    return result

# %%
results = stt_audio_file_wav('/media/Windows/root/AusKidTalkv2/sample.wav')
# Out:
# en-AU_BroadbandModel /media/Windows/root/AusKidTalkv2/sample.wav
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...

# %%
results
# Out:
# [{'result_index': 0,
#   'speaker_labels': [{'speaker': 2,
#     'confidence': 0.41,
#     'final': False,
#     'from': 2.37,
#     'to': 2.59},
#    {'speaker': 2,
#     'confidence': 0.41,
#     'final': False,
#     'from': 2.59,
#     'to': 2.75},
#    {'speaker': 2,
#     'confidence': 0.41,
#     'final': False,
#     'from': 2.75,
#     'to': 3.43},
#    {'speaker': 2,
#     'confidence': 0.41,
#     'final': False,
#     'from': 3.43,
#     'to': 3.71},
#    {'speaker': 2,
#     'confidence': 0.41,
#     'final': False,
#     'from': 3.71,
#     'to': 4.26},
#    {'speaker': 2,
#     'confidence': 0.37,
#     'final': False,
#     'from': 5.07,
#     'to': 5.22},
#    {'speaker': 2,
#     'confidence': 0.37,
#     'final': False,
#     'from': 5.22,
#     'to': 5.87},
#    {'speaker': 2, 'confidence': 0.42, 'final': False, 'from': 5.9, 'to': 6.41},
#    {'speaker': 2,
#     'confidence': 0.42,
#     'final': False,
#     'from': 6.44,
#     'to': 6.94},
#    {'speaker': 2,
#     'confidence': 0.42,
#     'final': False,
#     'from': 6.94,
#     'to': 7.44},
#    {'speaker': 3,
#     'confidence': 0.36,
#     'final': False,
#     'from': 9.07,
#     'to': 9.56},
#    {'speaker': 3,
#     'confidence': 0.36,
#     'final': False,
#     'from': 9.56,
#     'to': 9.96},
#    {'speaker': 3,
#     'confidence': 0.36,
#     'final': False,
#     'from': 9.96,
#     'to': 10.42},
#    {'speaker': 3,
#     'confidence': 0.36,
#     'final': False,
#     'from': 10.42,
#     'to': 11.12},
#    {'speaker': 2,
#     'confidence': 0.38,
#     'final': False,
#     'from': 11.44,
#     'to': 11.95},
#    {'speaker': 2,
#     'confidence': 0.38,
#     'final': False,
#     'from': 11.95,
#     'to': 12.11},
#    {'speaker': 2,
#     'confidence': 0.38,
#     'final': False,
#     'from': 12.11,
#     'to': 12.15},
#    {'speaker': 2,
#     'confidence': 0.38,
#     'final': False,
#     'from': 12.15,
#     'to': 12.52},
#    {'speaker': 2,
#     'confidence': 0.38,
#     'final': False,
#     'from': 12.52,
#     'to': 12.85},
#    {'speaker': 2,
#     'confidence': 0.38,
#     'final': False,
#     'from': 12.85,
#     'to': 13.1},
#    {'speaker': 2,
#     'confidence': 0.38,
#     'final': False,
#     'from': 13.1,
#     'to': 13.23},
#    {'speaker': 2,
#     'confidence': 0.38,
#     'final': False,
#     'from': 13.23,
#     'to': 13.63},
#    {'speaker': 2,
#     'confidence': 0.33,
#     'final': False,
#     'from': 14.11,
#     'to': 14.55},
#    {'speaker': 2,
#     'confidence': 0.41,
#     'final': False,
#     'from': 14.58,
#     'to': 14.73},
#    {'speaker': 2, 'confidence': 0.41, 'final': False, 'from': 14.73, 'to': 15},
#    {'speaker': 2, 'confidence': 0.41, 'final': False, 'from': 15, 'to': 15.23},
#    {'speaker': 2,
#     'confidence': 0.41,
#     'final': False,
#     'from': 15.23,
#     'to': 15.55},
#    {'speaker': 2,
#     'confidence': 0.41,
#     'final': False,
#     'from': 15.55,
#     'to': 15.75},
#    {'speaker': 2,
#     'confidence': 0.41,
#     'final': False,
#     'from': 15.75,
#     'to': 15.87},
#    {'speaker': 2, 'confidence': 0.41, 'final': False, 'from': 15.87, 'to': 16},
#    {'speaker': 2, 'confidence': 0.41, 'final': False, 'from': 16, 'to': 16.22},
#    {'speaker': 2,
#     'confidence': 0.41,
#     'final': False,
#     'from': 16.22,
#     'to': 16.33},
#    {'speaker': 2,
#     'confidence': 0.41,
#     'final': False,
#     'from': 16.33,
#     'to': 16.71},
#    {'speaker': 2,
#     'confidence': 0.42,
#     'final': False,
#     'from': 16.89,
#     'to': 17.25},
#    {'speaker': 2,
#     'confidence': 0.42,
#     'final': False,
#     'from': 17.25,
#     'to': 17.56},
#    {'speaker': 2,
#     'confidence': 0.42,
#     'final': False,
#     'from': 17.56,
#     'to': 17.76},
#    {'speaker': 2,
#     'confidence': 0.42,
#     'final': False,
#     'from': 17.76,
#     'to': 18.18},
#    {'speaker': 2,
#     'confidence': 0.37,
#     'final': False,
#     'from': 18.21,
#     'to': 18.39},
#    {'speaker': 2,
#     'confidence': 0.37,
#     'final': False,
#     'from': 18.39,
#     'to': 18.5},
#    {'speaker': 2,
#     'confidence': 0.37,
#     'final': False,
#     'from': 18.5,
#     'to': 18.87},
#    {'speaker': 2,
#     'confidence': 0.4,
#     'final': False,
#     'from': 18.92,
#     'to': 19.4},
#    {'speaker': 2,
#     'confidence': 0.4,
#     'final': False,
#     'from': 19.4,
#     'to': 19.74},
#    {'speaker': 2, 'confidence': 0.4, 'final': False, 'from': 23, 'to': 23.45},
#    {'speaker': 2,
#     'confidence': 0.33,
#     'final': False,
#     'from': 23.58,
#     'to': 24.15},
#    {'speaker': 2,
#     'confidence': 0.33,
#     'final': False,
#     'from': 24.15,
#     'to': 24.55},
#    {'speaker': 2,
#     'confidence': 0.33,
#     'final': False,
#     'from': 24.55,
#     'to': 24.73},
#    {'speaker': 2,
#     'confidence': 0.33,
#     'final': False,
#     'from': 24.73,
#     'to': 25.43},
#    {'speaker': 3,
#     'confidence': 0.37,
#     'final': False,
#     'from': 26.8,
#     'to': 27.44},
#    {'speaker': 3,
#     'confidence': 0.44,
#     'final': False,
#     'from': 27.47,
#     'to': 27.88},
#    {'speaker': 3,
#     'confidence': 0.44,
#     'final': False,
#     'from': 27.88,
#     'to': 28.42},
#    {'speaker': 3,
#     'confidence': 0.44,
#     'final': False,
#     'from': 28.42,
#     'to': 28.55},
#    {'speaker': 3,
#     'confidence': 0.44,
#     'final': False,
#     'from': 28.55,
#     'to': 28.97},
#    {'speaker': 2,
#     'confidence': 0.46,
#     'final': False,
#     'from': 29.96,
#     'to': 30.28},
#    {'speaker': 2,
#     'confidence': 0.46,
#     'final': False,
#     'from': 30.28,
#     'to': 30.4},
#    {'speaker': 2,
#     'confidence': 0.46,
#     'final': False,
#     'from': 30.4,
#     'to': 30.52},
#    {'speaker': 2,
#     'confidence': 0.46,
#     'final': False,
#     'from': 30.52,
#     'to': 30.8},
#    {'speaker': 2,
#     'confidence': 0.47,
#     'final': False,
#     'from': 30.84,
#     'to': 30.94},
#    {'speaker': 2,
#     'confidence': 0.47,
#     'final': False,
#     'from': 30.94,
#     'to': 31.26},
#    {'speaker': 2,
#     'confidence': 0.39,
#     'final': False,
#     'from': 31.32,
#     'to': 31.54},
#    {'speaker': 2,
#     'confidence': 0.39,
#     'final': False,
#     'from': 31.54,
#     'to': 31.64},
#    {'speaker': 2,
#     'confidence': 0.39,
#     'final': False,
#     'from': 31.64,
#     'to': 32.08},
#    {'speaker': 2,
#     'confidence': 0.34,
#     'final': False,
#     'from': 34.07,
#     'to': 34.55},
#    {'speaker': 2,
#     'confidence': 0.34,
#     'final': False,
#     'from': 34.55,
#     'to': 34.94},
#    {'speaker': 2,
#     'confidence': 0.34,
#     'final': False,
#     'from': 34.94,
#     'to': 35.11},
#    {'speaker': 2,
#     'confidence': 0.34,
#     'final': False,
#     'from': 35.11,
#     'to': 35.55},
#    {'speaker': 2,
#     'confidence': 0.34,
#     'final': False,
#     'from': 35.55,
#     'to': 35.7},
#    {'speaker': 2,
#     'confidence': 0.34,
#     'final': False,
#     'from': 35.7,
#     'to': 36.22},
#    {'speaker': 2,
#     'confidence': 0.33,
#     'final': False,
#     'from': 36.3,
#     'to': 36.65},
#    {'speaker': 2,
#     'confidence': 0.33,
#     'final': False,
#     'from': 36.65,
#     'to': 36.79},
#    {'speaker': 2,
#     'confidence': 0.33,
#     'final': False,
#     'from': 36.79,
#     'to': 37.25},
#    {'speaker': 2,
#     'confidence': 0.31,
#     'final': False,
#     'from': 37.3,
#     'to': 37.97},
#    {'speaker': 3,
#     'confidence': 0.38,
#     'final': False,
#     'from': 39.04,
#     'to': 39.44},
#    {'speaker': 3,
#     'confidence': 0.38,
#     'final': False,
#     'from': 39.44,
#     'to': 39.7},
#    {'speaker': 3,
#     'confidence': 0.38,
#     'final': False,
#     'from': 39.7,
#     'to': 39.86},
#    {'speaker': 3,
#     'confidence': 0.38,
#     'final': False,
#     'from': 39.86,
#     'to': 40.19},
#    {'speaker': 3,
#     'confidence': 0.38,
#     'final': False,
#     'from': 40.19,
#     'to': 40.32},
#    {'speaker': 3,
#     'confidence': 0.38,
#     'final': False,
#     'from': 40.32,
#     'to': 40.6},
#    {'speaker': 3,
#     'confidence': 0.38,
#     'final': False,
#     'from': 40.6,
#     'to': 40.97},
#    {'speaker': 3,
#     'confidence': 0.38,
#     'final': False,
#     'from': 40.97,
#     'to': 41.09},
#    {'speaker': 3,
#     'confidence': 0.38,
#     'final': False,
#     'from': 41.09,
#     'to': 41.38},
#    {'speaker': 3,
#     'confidence': 0.38,
#     'final': False,
#     'from': 41.38,
#     'to': 41.99},
#    {'speaker': 2,
#     'confidence': 0.3,
#     'final': False,
#     'from': 43.6,
#     'to': 44.14},
#    {'speaker': 2,
#     'confidence': 0.39,
#     'final': False,
#     'from': 44.2,
#     'to': 44.65},
#    {'speaker': 2,
#     'confidence': 0.39,
#     'final': False,
#     'from': 44.65,
#     'to': 45.22},
#    {'speaker': 2,
#     'confidence': 0.39,
#     'final': False,
#     'from': 45.22,
#     'to': 46.06},
#    {'speaker': 3,
#     'confidence': 0.39,
#     'final': False,
#     'from': 47.21,
#     'to': 47.68},
#    {'speaker': 3,
#     'confidence': 0.45,
#     'final': False,
#     'from': 47.71,
#     'to': 48.1},
#    {'speaker': 3,
#     'confidence': 0.45,
#     'final': False,
#     'from': 48.1,
#     'to': 48.52},
#    {'speaker': 3,
#     'confidence': 0.45,
#     'final': False,
#     'from': 48.52,
#     'to': 49.17},
#    {'speaker': 2,
#     'confidence': 0.4,
#     'final': False,
#     'from': 50.82,
#     'to': 51.36},
#    {'speaker': 2,
#     'confidence': 0.39,
#     'final': False,
#     'from': 51.39,
#     'to': 51.86},
#    {'speaker': 2,
#     'confidence': 0.39,
#     'final': False,
#     'from': 51.86,
#     'to': 52.33},
#    {'speaker': 2,
#     'confidence': 0.41,
#     'final': False,
#     'from': 52.36,
#     'to': 52.57},
#    {'speaker': 2,
#     'confidence': 0.41,
#     'final': False,
#     'from': 52.57,
#     'to': 53.51},
#    {'speaker': 3,
#     'confidence': 0.43,
#     'final': False,
#     'from': 54.7,
#     'to': 55.19},
#    {'speaker': 3,
#     'confidence': 0.46,
#     'final': False,
#     'from': 55.22,
#     'to': 55.6},
#    {'speaker': 3,
#     'confidence': 0.46,
#     'final': False,
#     'from': 55.6,
#     'to': 55.93},
#    {'speaker': 3,
#     'confidence': 0.46,
#     'final': False,
#     'from': 55.93,
#     'to': 56.13},
#    {'speaker': 3,
#     'confidence': 0.46,
#     'final': False,
#     'from': 56.13,
#     'to': 56.82},
#    {'speaker': 2,
#     'confidence': 0.42,
#     'final': False,
#     'from': 58.32,
#     'to': 58.86},
#    {'speaker': 2,
#     'confidence': 0.36,
#     'final': False,
#     'from': 58.89,
#     'to': 59.36},
#    {'speaker': 2,
#     'confidence': 0.36,
#     'final': False,
#     'from': 59.36,
#     'to': 59.82},
#    {'speaker': 2,
#     'confidence': 0.37,
#     'final': False,
#     'from': 59.89,
#     'to': 60.23},
#    {'speaker': 2,
#     'confidence': 0.38,
#     'final': False,
#     'from': 60.29,
#     'to': 61.16},
#    {'speaker': 3,
#     'confidence': 0.45,
#     'final': False,
#     'from': 62.53,
#     'to': 63.02},
#    {'speaker': 3,
#     'confidence': 0.41,
#     'final': False,
#     'from': 63.05,
#     'to': 63.44},
#    {'speaker': 3,
#     'confidence': 0.41,
#     'final': False,
#     'from': 63.44,
#     'to': 63.86},
#    {'speaker': 3,
#     'confidence': 0.44,
#     'final': False,
#     'from': 63.9,
#     'to': 64.18},
#    {'speaker': 3,
#     'confidence': 0.44,
#     'final': False,
#     'from': 64.18,
#     'to': 64.98},
#    {'speaker': 2,
#     'confidence': 0.4,
#     'final': False,
#     'from': 66.64,
#     'to': 67.2},
#    {'speaker': 2,
#     'confidence': 0.37,
#     'final': False,
#     'from': 67.26,
#     'to': 67.76},
#    {'speaker': 2,
#     'confidence': 0.37,
#     'final': False,
#     'from': 67.76,
#     'to': 68.24},
#    {'speaker': 2,
#     'confidence': 0.36,
#     'final': False,
#     'from': 68.29,
#     'to': 69.2},
#    {'speaker': 3,
#     'confidence': 0.45,
#     'final': False,
#     'from': 70.24,
#     'to': 70.68},
#    {'speaker': 3,
#     'confidence': 0.45,
#     'final': False,
#     'from': 70.71,
#     'to': 71.08},
#    {'speaker': 3,
#     'confidence': 0.45,
#     'final': False,
#     'from': 71.08,
#     'to': 71.49},
#    {'speaker': 3,
#     'confidence': 0.41,
#     'final': False,
#     'from': 71.52,
#     'to': 72.27},
#    {'speaker': 2,
#     'confidence': 0.4,
#     'final': False,
#     'from': 73.4,
#     'to': 73.92},
#    {'speaker': 2,
#     'confidence': 0.41,
#     'final': False,
#     'from': 73.96,
#     'to': 74.15},
#    {'speaker': 2,
#     'confidence': 0.41,
#     'final': False,
#     'from': 74.15,
#     'to': 74.94},
#    {'speaker': 2,
#     'confidence': 0.41,
#     'final': False,
#     'from': 74.94,
#     'to': 75.77},
#    {'speaker': 3,
#     'confidence': 0.47,
#     'final': False,
#     'from': 76.91,
#     'to': 77.36},
#    {'speaker': 3,
#     'confidence': 0.44,
#     'final': False,
#     'from': 77.4,
#     'to': 77.84},
#    {'speaker': 3,
#     'confidence': 0.44,
#     'final': False,
#     'from': 77.84,
#     'to': 78.23},
#    {'speaker': 3,
#     'confidence': 0.44,
#     'final': False,
#     'from': 78.23,
#     'to': 78.85},
#    {'speaker': 2,
#     'confidence': 0.39,
#     'final': False,
#     'from': 79.94,
#     'to': 80.4},
#    {'speaker': 2,
#     'confidence': 0.36,
#     'final': False,
#     'from': 80.52,
#     'to': 80.96},
#    {'speaker': 2,
#     'confidence': 0.36,
#     'final': False,
#     'from': 80.96,
#     'to': 81.32},
#    {'speaker': 2,
#     'confidence': 0.29,
#     'final': False,
#     'from': 81.42,
#     'to': 81.91},
#    {'speaker': 2,
#     'confidence': 0.37,
#     'final': False,
#     'from': 81.94,
#     'to': 82.79},
#    {'speaker': 3,
#     'confidence': 0.45,
#     'final': False,
#     'from': 83.92,
#     'to': 84.41},
#    {'speaker': 3,
#     'confidence': 0.45,
#     'final': False,
#     'from': 84.44,
#     'to': 84.84},
#    {'speaker': 3,
#     'confidence': 0.45,
#     'final': False,
#     'from': 84.84,
#     'to': 85.25},
#    {'speaker': 3,
#     'confidence': 0.44,
#     'final': False,
#     'from': 85.28,
#     'to': 85.69},
#    {'speaker': 3,
#     'confidence': 0.44,
#     'final': False,
#     'from': 85.69,
#     'to': 86.44},
#    {'speaker': 2,
#     'confidence': 0.41,
#     'final': False,
#     'from': 87.49,
#     'to': 87.99},
#    {'speaker': 2,
#     'confidence': 0.36,
#     'final': False,
#     'from': 88.12,
#     'to': 88.58},
#    {'speaker': 2,
#     'confidence': 0.36,
#     'final': False,
#     'from': 88.58,
#     'to': 88.81},
#    {'speaker': 2,
#     'confidence': 0.36,
#     'final': False,
#     'from': 89.22,
#     'to': 90.07},
#    {'speaker': 3,
#     'confidence': 0.44,
#     'final': False,
#     'from': 91.38,
#     'to': 91.83},
#    {'speaker': 3,
#     'confidence': 0.46,
#     'final': False,
#     'from': 91.87,
#     'to': 92.29},
#    {'speaker': 3,
#     'confidence': 0.46,
#     'final': False,
#     'from': 92.29,
#     'to': 92.6},
#    {'speaker': 3,
#     'confidence': 0.41,
#     'final': False,
#     'from': 92.63,
#     'to': 92.76},
#    {'speaker': 3,
#     'confidence': 0.41,
#     'final': False,
#     'from': 92.76,
#     'to': 93.41},
#    {'speaker': 2,
#     'confidence': 0.43,
#     'final': False,
#     'from': 94.57,
#     'to': 95.14},
#    {'speaker': 2,
#     'confidence': 0.37,
#     'final': False,
#     'from': 95.17,
#     'to': 95.61},
#    {'speaker': 2,
#     'confidence': 0.37,
#     'final': False,
#     'from': 95.61,
#     'to': 96.13},
#    {'speaker': 2,
#     'confidence': 0.45,
#     'final': False,
#     'from': 96.18,
#     'to': 96.33},
#    {'speaker': 2,
#     'confidence': 0.45,
#     'final': False,
#     'from': 96.33,
#     'to': 97.18},
#    {'speaker': 3,
#     'confidence': 0.44,
#     'final': False,
#     'from': 98.27,
#     'to': 98.73},
#    {'speaker': 3,
#     'confidence': 0.46,
#     'final': False,
#     'from': 98.77,
#     'to': 99.11},
#    {'speaker': 3,
#     'confidence': 0.46,
#     'final': False,
#     'from': 99.11,
#     'to': 99.56},
#    {'speaker': 3,
#     'confidence': 0.46,
#     'final': False,
#     'from': 99.56,
#     'to': 99.67},
#    {'speaker': 3,
#     'confidence': 0.46,
#     'final': False,
#     'from': 99.67,
#     'to': 100.26},
#    {'speaker': 2,
#     'confidence': 0.4,
#     'final': False,
#     'from': 101.22,
#     'to': 101.65},
#    {'speaker': 2,
#     'confidence': 0.4,
#     'final': False,
#     'from': 101.65,
#     'to': 101.77},
#    {'speaker': 2,
#     'confidence': 0.4,
#     'final': False,
#     'from': 101.81,
#     'to': 102.27},
#    {'speaker': 2,
#     'confidence': 0.4,
#     'final': False,
#     'from': 102.27,
#     'to': 102.66},
#    {'speaker': 2,
#     'confidence': 0.4,
#     'final': False,
#     'from': 102.66,
#     'to': 103.31},
#    {'speaker': 2,
#     'confidence': 0.4,
#     'final': False,
#     'from': 103.31,
#     'to': 104.08},
#    {'speaker': 3,
#     'confidence': 0.45,
#     'final': False,
#     'from': 105.09,
#     'to': 105.53},
#    {'speaker': 3,
#     'confidence': 0.57,
#     'final': False,
#     'from': 105.57,
#     'to': 105.94},
#    {'speaker': 3,
#     'confidence': 0.57,
#     'final': False,
#     'from': 105.94,
#     'to': 106.43},
#    {'speaker': 3,
#     'confidence': 0.57,
#     'final': False,
#     'from': 106.43,
#     'to': 106.91},
#    {'speaker': 3,
#     'confidence': 0.55,
#     'final': False,
#     'from': 106.94,
#     'to': 107.49},
#    {'speaker': 2,
#     'confidence': 0.6,
#     'final': False,
#     'from': 108.59,
#     'to': 109.17},
#    {'speaker': 2,
#     'confidence': 0.6,
#     'final': False,
#     'from': 109.17,
#     'to': 109.53},
#    {'speaker': 2,
#     'confidence': 0.6,
#     'final': False,
#     'from': 109.53,
#     'to': 109.68},
#    {'speaker': 2,
#     'confidence': 0.6,
#     'final': False,
#     'from': 109.68,
#     'to': 110.07},
#    {'speaker': 2,
#     'confidence': 0.6,
#     'final': False,
#     'from': 110.07,
#     'to': 110.27},
#    {'speaker': 2,
#     'confidence': 0.6,
#     'final': False,
#     'from': 110.27,
#     'to': 110.81},
#    {'speaker': 3,
#     'confidence': 0.49,
#     'final': False,
#     'from': 112.08,
#     'to': 112.65},
#    {'speaker': 3,
#     'confidence': 0.49,
#     'final': False,
#     'from': 112.65,
#     'to': 112.92},
#    {'speaker': 3,
#     'confidence': 0.49,
#     'final': False,
#     'from': 112.92,
#     'to': 113.07},
#    {'speaker': 3,
#     'confidence': 0.49,
#     'final': False,
#     'from': 113.07,
#     'to': 113.34},
#    {'speaker': 3,
#     'confidence': 0.49,
#     'final': False,
#     'from': 113.34,
#     'to': 113.49},
#    {'speaker': 3,
#     'confidence': 0.49,
#     'final': False,
#     'from': 113.49,
#     'to': 114},
#    {'speaker': 2,
#     'confidence': 0.48,
#     'final': False,
#     'from': 115.25,
#     'to': 115.8},
#    {'speaker': 2,
#     'confidence': 0.47,
#     'final': False,
#     'from': 115.84,
#     'to': 116.35},
#    {'speaker': 2,
#     'confidence': 0.5,
#     'final': False,
#     'from': 116.38,
#     'to': 116.83},
#    {'speaker': 2,
#     'confidence': 0.5,
#     'final': False,
#     'from': 116.83,
#     'to': 117.81},
#    {'speaker': 3,
#     'confidence': 0.55,
#     'final': False,
#     'from': 118.83,
#     'to': 119.19},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 119.27,
#     'to': 119.66},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 119.66,
#     'to': 120.07},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 120.07,
#     'to': 120.9},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 122.44,
#     'to': 123.11},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 123.11,
#     'to': 123.68},
#    {'speaker': 2,
#     'confidence': 0.43,
#     'final': False,
#     'from': 123.71,
#     'to': 124.14},
#    {'speaker': 2,
#     'confidence': 0.44,
#     'final': False,
#     'from': 124.18,
#     'to': 125.03},
#    {'speaker': 3,
#     'confidence': 0.54,
#     'final': False,
#     'from': 126.16,
#     'to': 126.89},
#    {'speaker': 3,
#     'confidence': 0.54,
#     'final': False,
#     'from': 126.92,
#     'to': 127.35},
#    {'speaker': 3,
#     'confidence': 0.54,
#     'final': False,
#     'from': 127.35,
#     'to': 127.78},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 127.81,
#     'to': 128.55},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 129.53,
#     'to': 130.05},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 130.09,
#     'to': 130.59},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 130.59,
#     'to': 131.05},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 131.05,
#     'to': 132.01},
#    {'speaker': 3,
#     'confidence': 0.54,
#     'final': False,
#     'from': 133.12,
#     'to': 133.6},
#    {'speaker': 3,
#     'confidence': 0.57,
#     'final': False,
#     'from': 133.63,
#     'to': 134.14},
#    {'speaker': 3,
#     'confidence': 0.57,
#     'final': False,
#     'from': 134.14,
#     'to': 134.53},
#    {'speaker': 3,
#     'confidence': 0.52,
#     'final': False,
#     'from': 134.6,
#     'to': 135.39},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 137.19,
#     'to': 137.69},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 137.69,
#     'to': 138.2},
#    {'speaker': 2,
#     'confidence': 0.5,
#     'final': False,
#     'from': 138.68,
#     'to': 139.49},
#    {'speaker': 3,
#     'confidence': 0.55,
#     'final': False,
#     'from': 140.8,
#     'to': 141.26},
#    {'speaker': 3,
#     'confidence': 0.54,
#     'final': False,
#     'from': 141.29,
#     'to': 141.82},
#    {'speaker': 3,
#     'confidence': 0.52,
#     'final': False,
#     'from': 142.09,
#     'to': 142.56},
#    {'speaker': 3,
#     'confidence': 0.53,
#     'final': False,
#     'from': 142.59,
#     'to': 143.29},
#    {'speaker': 2,
#     'confidence': 0.56,
#     'final': False,
#     'from': 144.35,
#     'to': 144.84},
#    {'speaker': 2,
#     'confidence': 0.56,
#     'final': False,
#     'from': 144.84,
#     'to': 145.31},
#    {'speaker': 2,
#     'confidence': 0.56,
#     'final': False,
#     'from': 145.31,
#     'to': 145.85},
#    {'speaker': 2,
#     'confidence': 0.56,
#     'final': False,
#     'from': 145.85,
#     'to': 146.74},
#    {'speaker': 3,
#     'confidence': 0.53,
#     'final': False,
#     'from': 148.4,
#     'to': 148.84},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 148.87,
#     'to': 149.29},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 149.29,
#     'to': 149.71},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 149.71,
#     'to': 150.63},
#    {'speaker': 2,
#     'confidence': 0.54,
#     'final': False,
#     'from': 151.96,
#     'to': 152.53},
#    {'speaker': 2,
#     'confidence': 0.53,
#     'final': False,
#     'from': 152.57,
#     'to': 153.08},
#    {'speaker': 2,
#     'confidence': 0.53,
#     'final': False,
#     'from': 153.08,
#     'to': 153.57},
#    {'speaker': 2,
#     'confidence': 0.55,
#     'final': False,
#     'from': 153.61,
#     'to': 154.4},
#    {'speaker': 3,
#     'confidence': 0.54,
#     'final': False,
#     'from': 155.65,
#     'to': 156.1},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 156.13,
#     'to': 156.51},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 156.51,
#     'to': 156.95},
#    {'speaker': 3,
#     'confidence': 0.37,
#     'final': False,
#     'from': 156.98,
#     'to': 157.62},
#    {'speaker': 2,
#     'confidence': 0.56,
#     'final': False,
#     'from': 159.85,
#     'to': 160.54},
#    {'speaker': 2,
#     'confidence': 0.56,
#     'final': False,
#     'from': 160.54,
#     'to': 161.06},
#    {'speaker': 2,
#     'confidence': 0.56,
#     'final': False,
#     'from': 161.06,
#     'to': 161.53},
#    {'speaker': 2,
#     'confidence': 0.56,
#     'final': False,
#     'from': 161.53,
#     'to': 162.35},
#    {'speaker': 3,
#     'confidence': 0.53,
#     'final': False,
#     'from': 163.6,
#     'to': 164.23},
#    {'speaker': 3,
#     'confidence': 0.58,
#     'final': False,
#     'from': 164.26,
#     'to': 164.73},
#    {'speaker': 3,
#     'confidence': 0.58,
#     'final': False,
#     'from': 164.73,
#     'to': 165.17},
#    {'speaker': 3,
#     'confidence': 0.53,
#     'final': False,
#     'from': 165.2,
#     'to': 165.91},
#    {'speaker': 2,
#     'confidence': 0.52,
#     'final': False,
#     'from': 166.88,
#     'to': 167.41},
#    {'speaker': 2,
#     'confidence': 0.51,
#     'final': False,
#     'from': 167.45,
#     'to': 167.88},
#    {'speaker': 2,
#     'confidence': 0.51,
#     'final': False,
#     'from': 167.88,
#     'to': 168.49},
#    {'speaker': 2,
#     'confidence': 0.54,
#     'final': False,
#     'from': 168.52,
#     'to': 169.25},
#    {'speaker': 3,
#     'confidence': 0.56,
#     'final': False,
#     'from': 170.18,
#     'to': 170.6},
#    {'speaker': 3,
#     'confidence': 0.5,
#     'final': False,
#     'from': 170.63,
#     'to': 171},
#    {'speaker': 3,
#     'confidence': 0.5,
#     'final': False,
#     'from': 171,
#     'to': 171.48},
#    {'speaker': 3,
#     'confidence': 0.5,
#     'final': False,
#     'from': 171.48,
#     'to': 172.04},
#    {'speaker': 2,
#     'confidence': 0.38,
#     'final': False,
#     'from': 173.52,
#     'to': 173.67},
#    {'speaker': 2,
#     'confidence': 0.38,
#     'final': False,
#     'from': 173.67,
#     'to': 173.92},
#    {'speaker': 2,
#     'confidence': 0.49,
#     'final': False,
#     'from': 174.89,
#     'to': 175.44},
#    {'speaker': 2,
#     'confidence': 0.53,
#     'final': False,
#     'from': 175.48,
#     'to': 175.94},
#    {'speaker': 2,
#     'confidence': 0.53,
#     'final': False,
#     'from': 175.94,
#     'to': 176.41},
#    {'speaker': 2,
#     'confidence': 0.53,
#     'final': False,
#     'from': 176.41,
#     'to': 177.28},
#    {'speaker': 3,
#     'confidence': 0.52,
#     'final': False,
#     'from': 178.32,
#     'to': 178.79},
#    {'speaker': 3,
#     'confidence': 0.6,
#     'final': False,
#     'from': 178.82,
#     'to': 179.22},
#    {'speaker': 3,
#     'confidence': 0.6,
#     'final': False,
#     'from': 179.22,
#     'to': 179.65},
#    {'speaker': 3,
#     'confidence': 0.52,
#     'final': False,
#     'from': 179.68,
#     'to': 180.44},
#    {'speaker': 3,
#     'confidence': 0.61,
#     'final': False,
#     'from': 185.58,
#     'to': 185.99},
#    {'speaker': 3,
#     'confidence': 0.54,
#     'final': False,
#     'from': 186.02,
#     'to': 186.36},
#    {'speaker': 3,
#     'confidence': 0.54,
#     'final': False,
#     'from': 186.36,
#     'to': 186.78},
#    {'speaker': 3,
#     'confidence': 0.54,
#     'final': False,
#     'from': 186.78,
#     'to': 187.34},
#    {'speaker': 2,
#     'confidence': 0.51,
#     'final': False,
#     'from': 189.23,
#     'to': 189.85},
#    {'speaker': 2,
#     'confidence': 0.51,
#     'final': False,
#     'from': 189.85,
#     'to': 190.31},
#    {'speaker': 2,
#     'confidence': 0.51,
#     'final': False,
#     'from': 190.31,
#     'to': 190.89},
#    {'speaker': 2,
#     'confidence': 0.58,
#     'final': False,
#     'from': 190.92,
#     'to': 191.6},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 192.65,
#     'to': 193.27},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 193.27,
#     'to': 193.68},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 193.68,
#     'to': 194.21},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 194.21,
#     'to': 194.8},
#    {'speaker': 2,
#     'confidence': 0.54,
#     'final': False,
#     'from': 196.08,
#     'to': 196.61},
#    {'speaker': 2,
#     'confidence': 0.53,
#     'final': False,
#     'from': 196.65,
#     'to': 197.12},
#    {'speaker': 2,
#     'confidence': 0.53,
#     'final': False,
#     'from': 197.12,
#     'to': 197.6},
#    {'speaker': 2,
#     'confidence': 0.46,
#     'final': False,
#     'from': 197.63,
#     'to': 198.48},
#    {'speaker': 3,
#     'confidence': 0.55,
#     'final': False,
#     'from': 199.43,
#     'to': 199.87},
#    {'speaker': 3,
#     'confidence': 0.54,
#     'final': False,
#     'from': 199.9,
#     'to': 200.29},
#    {'speaker': 3,
#     'confidence': 0.54,
#     'final': False,
#     'from': 200.29,
#     'to': 200.61},
#    {'speaker': 3,
#     'confidence': 0.54,
#     'final': False,
#     'from': 200.61,
#     'to': 201.31},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 202.42,
#     'to': 202.86},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 202.86,
#     'to': 203.25},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 203.25,
#     'to': 203.39},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 203.39,
#     'to': 203.85},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 203.85,
#     'to': 204.01},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 204.01,
#     'to': 204.43},
#    {'speaker': 2,
#     'confidence': 0.52,
#     'final': False,
#     'from': 204.47,
#     'to': 204.71},
#    {'speaker': 2,
#     'confidence': 0.52,
#     'final': False,
#     'from': 204.71,
#     'to': 204.84},
#    {'speaker': 2,
#     'confidence': 0.52,
#     'final': False,
#     'from': 204.84,
#     'to': 205.22},
#    {'speaker': 2,
#     'confidence': 0.52,
#     'final': False,
#     'from': 205.22,
#     'to': 206.28},
#    {'speaker': 3,
#     'confidence': 0.53,
#     'final': False,
#     'from': 207.31,
#     'to': 207.93},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 208.28,
#     'to': 208.75},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 208.75,
#     'to': 209.06},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 209.06,
#     'to': 209.51},
#    {'speaker': 3,
#     'confidence': 0.5,
#     'final': False,
#     'from': 209.56,
#     'to': 209.95},
#    {'speaker': 3,
#     'confidence': 0.5,
#     'final': False,
#     'from': 209.95,
#     'to': 210.12},
#    {'speaker': 3,
#     'confidence': 0.5,
#     'final': False,
#     'from': 210.12,
#     'to': 210.42},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 210.45,
#     'to': 210.75},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 210.75,
#     'to': 210.87},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 210.87,
#     'to': 211.11},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 211.11,
#     'to': 211.8},
#    {'speaker': 2,
#     'confidence': 0.59,
#     'final': False,
#     'from': 213.26,
#     'to': 213.71},
#    {'speaker': 2,
#     'confidence': 0.59,
#     'final': False,
#     'from': 213.71,
#     'to': 214.09},
#    {'speaker': 2,
#     'confidence': 0.59,
#     'final': False,
#     'from': 214.09,
#     'to': 214.25},
#    {'speaker': 2,
#     'confidence': 0.59,
#     'final': False,
#     'from': 214.25,
#     'to': 214.7},
#    {'speaker': 2,
#     'confidence': 0.59,
#     'final': False,
#     'from': 214.7,
#     'to': 214.87},
#    {'speaker': 2,
#     'confidence': 0.59,
#     'final': False,
#     'from': 214.87,
#     'to': 215.32},
#    {'speaker': 2,
#     'confidence': 0.5,
#     'final': False,
#     'from': 215.37,
#     'to': 215.67},
#    {'speaker': 2,
#     'confidence': 0.5,
#     'final': False,
#     'from': 215.67,
#     'to': 215.85},
#    {'speaker': 2,
#     'confidence': 0.5,
#     'final': False,
#     'from': 215.85,
#     'to': 216.61},
#    {'speaker': 3,
#     'confidence': 0.61,
#     'final': False,
#     'from': 217.51,
#     'to': 217.9},
#    {'speaker': 3,
#     'confidence': 0.61,
#     'final': False,
#     'from': 217.9,
#     'to': 218.18},
#    {'speaker': 3,
#     'confidence': 0.61,
#     'final': False,
#     'from': 218.18,
#     'to': 218.31},
#    {'speaker': 3,
#     'confidence': 0.61,
#     'final': False,
#     'from': 218.31,
#     'to': 218.76},
#    {'speaker': 3,
#     'confidence': 0.61,
#     'final': False,
#     'from': 218.76,
#     'to': 218.93},
#    {'speaker': 3,
#     'confidence': 0.61,
#     'final': False,
#     'from': 218.93,
#     'to': 219.27},
#    {'speaker': 3,
#     'confidence': 0.49,
#     'final': False,
#     'from': 219.3,
#     'to': 219.51},
#    {'speaker': 3,
#     'confidence': 0.49,
#     'final': False,
#     'from': 219.51,
#     'to': 219.63},
#    {'speaker': 3,
#     'confidence': 0.49,
#     'final': False,
#     'from': 219.63,
#     'to': 220.15},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 221.79,
#     'to': 222.3},
#    {'speaker': 2,
#     'confidence': 0.61,
#     'final': False,
#     'from': 222.33,
#     'to': 222.83},
#    {'speaker': 2,
#     'confidence': 0.61,
#     'final': False,
#     'from': 222.83,
#     'to': 223.23},
#    {'speaker': 2,
#     'confidence': 0.61,
#     'final': False,
#     'from': 223.23,
#     'to': 223.4},
#    {'speaker': 2,
#     'confidence': 0.61,
#     'final': False,
#     'from': 223.4,
#     'to': 223.9},
#    {'speaker': 2,
#     'confidence': 0.29,
#     'final': False,
#     'from': 224.71,
#     'to': 224.79},
#    {'speaker': 3,
#     'confidence': 0.62,
#     'final': False,
#     'from': 225.28,
#     'to': 225.72},
#    {'speaker': 3,
#     'confidence': 0.62,
#     'final': False,
#     'from': 225.72,
#     'to': 226.11},
#    {'speaker': 3,
#     'confidence': 0.62,
#     'final': False,
#     'from': 226.11,
#     'to': 226.52},
#    {'speaker': 3,
#     'confidence': 0.62,
#     'final': False,
#     'from': 226.52,
#     'to': 226.62},
#    {'speaker': 3,
#     'confidence': 0.62,
#     'final': False,
#     'from': 226.62,
#     'to': 227.22},
#    {'speaker': 2,
#     'confidence': 0.61,
#     'final': False,
#     'from': 228.54,
#     'to': 229},
#    {'speaker': 2,
#     'confidence': 0.61,
#     'final': False,
#     'from': 229,
#     'to': 229.58},
#    {'speaker': 2,
#     'confidence': 0.61,
#     'final': False,
#     'from': 229.58,
#     'to': 230.06},
#    {'speaker': 2,
#     'confidence': 0.61,
#     'final': False,
#     'from': 230.06,
#     'to': 230.18},
#    {'speaker': 2,
#     'confidence': 0.61,
#     'final': False,
#     'from': 230.18,
#     'to': 230.58},
#    {'speaker': 2,
#     'confidence': 0.61,
#     'final': False,
#     'from': 230.58,
#     'to': 231.06},
#    {'speaker': 2,
#     'confidence': 0.61,
#     'final': False,
#     'from': 231.06,
#     'to': 231.16},
#    {'speaker': 2,
#     'confidence': 0.61,
#     'final': False,
#     'from': 231.16,
#     'to': 231.87},
#    {'speaker': 3,
#     'confidence': 0.53,
#     'final': False,
#     'from': 232.97,
#     'to': 233.49},
#    {'speaker': 3,
#     'confidence': 0.62,
#     'final': False,
#     'from': 233.52,
#     'to': 233.91},
#    {'speaker': 3,
#     'confidence': 0.62,
#     'final': False,
#     'from': 233.91,
#     'to': 234.34},
#    {'speaker': 3,
#     'confidence': 0.62,
#     'final': False,
#     'from': 234.34,
#     'to': 234.46},
#    {'speaker': 3,
#     'confidence': 0.62,
#     'final': False,
#     'from': 234.46,
#     'to': 234.8},
#    {'speaker': 3,
#     'confidence': 0.62,
#     'final': False,
#     'from': 234.8,
#     'to': 235.15},
#    {'speaker': 3,
#     'confidence': 0.62,
#     'final': False,
#     'from': 235.15,
#     'to': 235.25},
#    {'speaker': 3,
#     'confidence': 0.62,
#     'final': False,
#     'from': 235.25,
#     'to': 235.83},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 237.44,
#     'to': 237.6},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 237.6,
#     'to': 237.78},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 237.78,
#     'to': 238.33},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 238.33,
#     'to': 238.62},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 238.62,
#     'to': 238.79},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 238.79,
#     'to': 239.3},
#    {'speaker': 3,
#     'confidence': 0.6,
#     'final': False,
#     'from': 240.52,
#     'to': 241.1},
#    {'speaker': 3,
#     'confidence': 0.6,
#     'final': False,
#     'from': 241.1,
#     'to': 241.48},
#    {'speaker': 3,
#     'confidence': 0.6,
#     'final': False,
#     'from': 241.48,
#     'to': 241.73},
#    {'speaker': 3,
#     'confidence': 0.6,
#     'final': False,
#     'from': 241.73,
#     'to': 241.9},
#    {'speaker': 3,
#     'confidence': 0.6,
#     'final': False,
#     'from': 241.9,
#     'to': 242.51},
#    {'speaker': 2,
#     'confidence': 0.56,
#     'final': False,
#     'from': 243.81,
#     'to': 244.2},
#    {'speaker': 2,
#     'confidence': 0.56,
#     'final': False,
#     'from': 244.2,
#     'to': 244.52},
#    {'speaker': 2,
#     'confidence': 0.56,
#     'final': False,
#     'from': 244.52,
#     'to': 244.68},
#    {'speaker': 2,
#     'confidence': 0.56,
#     'final': False,
#     'from': 244.68,
#     'to': 245.08},
#    {'speaker': 2,
#     'confidence': 0.56,
#     'final': False,
#     'from': 245.08,
#     'to': 245.27},
#    {'speaker': 2,
#     'confidence': 0.56,
#     'final': False,
#     'from': 245.27,
#     'to': 245.7},
#    {'speaker': 2,
#     'confidence': 0.59,
#     'final': False,
#     'from': 245.73,
#     'to': 245.99},
#    {'speaker': 2,
#     'confidence': 0.59,
#     'final': False,
#     'from': 245.99,
#     'to': 246.14},
#    {'speaker': 2,
#     'confidence': 0.59,
#     'final': False,
#     'from': 246.14,
#     'to': 246.83},
#    {'speaker': 3,
#     'confidence': 0.53,
#     'final': False,
#     'from': 247.75,
#     'to': 248.3},
#    {'speaker': 3,
#     'confidence': 0.53,
#     'final': False,
#     'from': 248.3,
#     'to': 248.53},
#    {'speaker': 3,
#     'confidence': 0.53,
#     'final': False,
#     'from': 248.53,
#     'to': 248.68},
#    {'speaker': 3,
#     'confidence': 0.53,
#     'final': False,
#     'from': 248.68,
#     'to': 248.9},
#    {'speaker': 3,
#     'confidence': 0.53,
#     'final': False,
#     'from': 248.9,
#     'to': 249.04},
#    {'speaker': 3,
#     'confidence': 0.53,
#     'final': False,
#     'from': 249.04,
#     'to': 249.38},
#    {'speaker': 3,
#     'confidence': 0.49,
#     'final': False,
#     'from': 249.42,
#     'to': 249.6},
#    {'speaker': 3,
#     'confidence': 0.49,
#     'final': False,
#     'from': 249.6,
#     'to': 249.73},
#    {'speaker': 3,
#     'confidence': 0.49,
#     'final': False,
#     'from': 249.73,
#     'to': 250.25},
#    {'speaker': 2,
#     'confidence': 0.58,
#     'final': False,
#     'from': 251.57,
#     'to': 252.17},
#    {'speaker': 2,
#     'confidence': 0.58,
#     'final': False,
#     'from': 252.17,
#     'to': 252.53},
#    {'speaker': 2,
#     'confidence': 0.58,
#     'final': False,
#     'from': 252.53,
#     'to': 252.68},
#    {'speaker': 2,
#     'confidence': 0.58,
#     'final': False,
#     'from': 252.68,
#     'to': 253.08},
#    {'speaker': 2,
#     'confidence': 0.58,
#     'final': False,
#     'from': 253.08,
#     'to': 253.23},
#    {'speaker': 2,
#     'confidence': 0.58,
#     'final': False,
#     'from': 253.23,
#     'to': 253.69},
#    {'speaker': 2,
#     'confidence': 0.49,
#     'final': False,
#     'from': 253.72,
#     'to': 253.94},
#    {'speaker': 2,
#     'confidence': 0.49,
#     'final': False,
#     'from': 253.94,
#     'to': 254.06},
#    {'speaker': 2,
#     'confidence': 0.49,
#     'final': False,
#     'from': 254.06,
#     'to': 254.39},
#    {'speaker': 2,
#     'confidence': 0.49,
#     'final': False,
#     'from': 254.39,
#     'to': 255.48},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 256.49,
#     'to': 257.04},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 257.04,
#     'to': 257.27},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 257.27,
#     'to': 257.42},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 257.42,
#     'to': 257.64},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 257.64,
#     'to': 257.78},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 257.78,
#     'to': 258.1},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 258.1,
#     'to': 258.22},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 258.22,
#     'to': 258.32},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 258.32,
#     'to': 258.6},
#    {'speaker': 3,
#     'confidence': 0.59,
#     'final': False,
#     'from': 258.6,
#     'to': 259.42},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 260.85,
#     'to': 261.51},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 261.51,
#     'to': 262.1},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 262.1,
#     'to': 262.39},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 262.39,
#     'to': 262.58},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 262.58,
#     'to': 263.01},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 263.01,
#     'to': 263.54},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 263.54,
#     'to': 263.68},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 263.68,
#     'to': 264.14},
#    {'speaker': 2,
#     'confidence': 0.57,
#     'final': False,
#     'from': 264.14,
#     'to': 264.88},
#    {'speaker': 3,
#     'confidence': 0.61,
#     'final': False,
#     'from': 265.81,
#     'to': 266.39},
#    {'speaker': 3,
#     'confidence': 0.61,
#     'final': False,
#     'from': 266.39,
#     'to': 266.78},
#    {'speaker': 3,
#     'confidence': 0.61,
#     'final': False,
#     'from': 266.78,
#     'to': 267},
#    {'speaker': 3,
#     'confidence': 0.61,
#     'final': False,
#     'from': 267,
#     'to': 267.17},
#    {'speaker': 3,
#     'confidence': 0.61,
#     'final': False,
#     'from': 267.17,
#     'to': 267.54},
#    {'speaker': 3,
#     'confidence': 0.61,
#     'final': False,
#     'from': 267.54,
#     'to': 267.85},
#    {'speaker': 3,
#     'confidence': 0.61,
#     'final': False,
#     'from': 267.85,
#     'to': 267.96},
#    {'speaker': 3,
#     'confidence': 0.61,
#     'final': False,
#     'from': 267.96,
#     'to': 268.36},
#    {'speaker': 3,
#     'confidence': 0.61,
#     'final': False,
#     'from': 268.36,
#     'to': 268.88},
#    {'speaker': 2,
#     'confidence': 0.6,
#     'final': False,
#     'from': 270.14,
#     'to': 270.7},
#    {'speaker': 2,
#     'confidence': 0.6,
#     'final': False,
#     'from': 270.7,
#     'to': 271.26},
#    {'speaker': 2,
#     'confidence': 0.6,
#     'final': False,
#     'from': 271.26,
#     'to': 271.55},
#    {'speaker': 2,
#     'confidence': 0.6,
#     'final': False,
#     'from': 271.55,
#     'to': 271.76},
#    {'speaker': 2,
#     'confidence': 0.6,
#     'final': False,
#     'from': 271.76,
#     'to': 272.17},
#    {'speaker': 2,
#     'confidence': 0.6,
#     'final': False,
#     'from': 272.17,
#     'to': 272.61},
#    {'speaker': 2,
#     'confidence': 0.6,
#     'final': False,
#     'from': 272.61,
#     'to': 272.73},
#    {'speaker': 2,
#     'confidence': 0.6,
#     'final': False,
#     'from': 272.73,
#     'to': 273.48},
#    {'speaker': 3,
#     'confidence': 0.62,
#     'final': False,
#     'from': 274.5,
#     'to': 275.03},
#    {'speaker': 3,
#     'confidence': 0.62,
#     'final': False,
#     'from': 275.03,
#     'to': 275.4},
#    {'speaker': 3,
#     'confidence': 0.62,
#     'final': False,
#     'from': 275.4,
#     'to': 275.61},
#    {'speaker': 3,
#     'confidence': 0.62,
#     'final': False,
#     'from': 275.61,
#     'to': 275.79},
#    {'speaker': 3,
#     'confidence': 0.62,
#     'final': False,
#     'from': 275.79,
#     'to': 276.13},
#    {'speaker': 3,
#     'confidence': 0.62,
#     'final': False,
#     'from': 276.13,
#     'to': 276.43},
#    {'speaker': 3,
#     'confidence': 0.62,
#     'final': False,
#     'from': 276.43,
#     'to': 276.52},
#    {'speaker': 3,
#     'confidence': 0.62,
#     'final': False,
#     'from': 276.52,
#     'to': 277.01},
#    {'speaker': 2,
#     'confidence': 0.58,
#     'final': False,
#     'from': 278.73,
#     'to': 279.2},
#    {'speaker': 2,
#     'confidence': 0.58,
#     'final': False,
#     'from': 279.2,
#     'to': 279.74},
#    {'speaker': 2,
#     'confidence': 0.58,
#     'final': False,
#     'from': 279.74,
#     'to': 280.19},
#    {'speaker': 2,
#     'confidence': 0.58,
#     'final': False,
#     'from': 280.19,
#     'to': 280.29},
#    {'speaker': 2,
#     'confidence': 0.58,
#     'final': False,
#     'from': 280.29,
#     'to': 280.69},
#    {'speaker': 2,
#     'confidence': 0.58,
#     'final': False,
#     'from': 280.69,
#     'to': 281.2},
#    {'speaker': 2,
#     'confidence': 0.58,
#     'final': False,
#     'from': 281.2,
#     'to': 281.33},
#    {'speaker': 2,
#     'confidence': 0.58,
#     'final': False,
#     'from': 281.33,
#     'to': 281.8},
#    {'speaker': 2,
#     'confidence': 0.58,
#     'final': False,
#     'from': 281.8,
#     'to': 282.55},
#    {'speaker': 3,
#     'confidence': 0.58,
#     'final': False,
#     'from': 283.54,
#     'to': 284.07},
#    {'speaker': 3,
#     'confidence': 0.63,
#     'final': False,
#     'from': 284.1,
#     'to': 284.5},
#    {'speaker': 3,
#     'confidence': 0.63,
#     'final': False,
#     'from': 284.5,
#     'to': 284.93},
#    {'speaker': 3,
#     'confidence': 0.63,
#     'final': False,
#     'from': 284.93,
#     'to': 285.02},
#    {'speaker': 3,
#     'confidence': 0.63,
#     'final': False,
#     'from': 285.02,
#     'to': 285.38},
#    {'speaker': 3,
#     'confidence': 0.63,
#     'final': False,
#     'from': 285.38,
#     'to': 285.69},
#    {'speaker': 3,
#     'confidence': 0.63,
#     'final': False,
#     'from': 285.69,
#     'to': 285.79},
#    {'speaker': 3,
#     'confidence': 0.63,
#     'final': False,
#     'from': 285.79,
#     'to': 286.18},
#    {'speaker': 3,
#     'confidence': 0.63,
#     'final': False,
#     'from': 286.18,
#     'to': 286.71},
#    {'speaker': 2,
#     'confidence': 0.61,
#     'final': False,
#     'from': 287.73,
#     'to': 288.18},
#    {'speaker': 2,
#     'confidence': 0.61,
#     'final': False,
#     'from': 288.18,
#     'to': 288.56},
#    {'speaker': 2,
#     'confidence': 0.61,
#     'final': False,
#     'from': 288.56,
#     'to': 288.71},
#    {'speaker': 2,
#     'confidence': 0.61,
#     'final': False,
#     'from': 288.71,
#     'to': 289.12},
#    {'speaker': 2,
#     'confidence': 0.61,
#     'final': False,
#     'from': 289.12,
#     'to': 289.29},
#    {'speaker': 2,
#     'confidence': 0.61,
#     'final': False,
#     'from': 289.29,
#     'to': 289.78},
#    {'speaker': 3,
#     'confidence': 0.58,
#     'final': False,
#     'from': 290.98,
#     'to': 291.34},
#    {'speaker': 3,
#     'confidence': 0.58,
#     'final': False,
#     'from': 291.34,
#     'to': 291.6},
#    {'speaker': 3,
#     'confidence': 0.58,
#     'final': False,
#     'from': 291.6,
#     'to': 291.73},
#    {'speaker': 3,
#     'confidence': 0.58,
#     'final': False,
#     'from': 291.73,
#     'to': 292.09},
#    {'speaker': 3,
#     'confidence': 0.58,
#     'final': False,
#     'from': 292.09,
#     'to': 292.27},
#    {'speaker': 3,
#     'confidence': 0.58,
#     'final': True,
#     'from': 292.27,
#     'to': 292.61}],
#   'results': [{'final': True,
#     'alternatives': [{'transcript': 'got to practises though so ',
#       'timestamps': [['got', 2.37, 2.59],
#        ['to', 2.59, 2.75],
#        ['practises', 2.75, 3.43],
#        ['though', 3.43, 3.71],
#        ['so', 3.71, 4.26]],
#       'confidence': 0.94}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'the house often catch my ',
#       'timestamps': [['the', 5.07, 5.22],
#        ['house', 5.22, 5.87],
#        ['often', 5.9, 6.41],
#        ['catch', 6.44, 6.94],
#        ['my', 6.94, 7.44]],
#       'confidence': 0.55}]},
#    {'final': True,
#     'alternatives': [{'transcript': "cancel often catch mice interesting and I should also say as well %HESITATION you'll see a green light when it's time to talk people talk about early but you didn't perfectly then ",
#       'timestamps': [['cancel', 9.07, 9.56],
#        ['often', 9.56, 9.96],
#        ['catch', 9.96, 10.42],
#        ['mice', 10.42, 11.12],
#        ['interesting', 11.44, 11.95],
#        ['and', 11.95, 12.11],
#        ['I', 12.11, 12.15],
#        ['should', 12.15, 12.52],
#        ['also', 12.52, 12.85],
#        ['say', 12.85, 13.1],
#        ['as', 13.1, 13.23],
#        ['well', 13.23, 13.63],
#        ['%HESITATION', 14.11, 14.55],
#        ["you'll", 14.58, 14.73],
#        ['see', 14.73, 15],
#        ['a', 15, 15.23],
#        ['green', 15.23, 15.55],
#        ['light', 15.55, 15.75],
#        ['when', 15.75, 15.87],
#        ["it's", 15.87, 16],
#        ['time', 16, 16.22],
#        ['to', 16.22, 16.33],
#        ['talk', 16.33, 16.71],
#        ['people', 16.89, 17.25],
#        ['talk', 17.25, 17.56],
#        ['about', 17.56, 17.76],
#        ['early', 17.76, 18.18],
#        ['but', 18.21, 18.39],
#        ['you', 18.39, 18.5],
#        ["didn't", 18.5, 18.87],
#        ['perfectly', 18.92, 19.4],
#        ['then', 19.4, 19.74]],
#       'confidence': 0.92}]},
#    {'final': True,
#     'alternatives': [{'transcript': "hasn't always pour the tea ",
#       'timestamps': [["hasn't", 23, 23.45],
#        ['always', 23.58, 24.15],
#        ['pour', 24.15, 24.55],
#        ['the', 24.55, 24.73],
#        ['tea', 24.73, 25.43]],
#       'confidence': 0.87}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'cousins always pour the tea ',
#       'timestamps': [['cousins', 26.8, 27.44],
#        ['always', 27.47, 27.88],
#        ['pour', 27.88, 28.42],
#        ['the', 28.42, 28.55],
#        ['tea', 28.55, 28.97]],
#       'confidence': 0.96}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'exactly what we want all right ready to start ',
#       'timestamps': [['exactly', 29.96, 30.28],
#        ['what', 30.28, 30.4],
#        ['we', 30.4, 30.52],
#        ['want', 30.52, 30.8],
#        ['all', 30.84, 30.94],
#        ['right', 30.94, 31.26],
#        ['ready', 31.32, 31.54],
#        ['to', 31.54, 31.64],
#        ['start', 31.64, 32.08]],
#       'confidence': 0.92}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'dogs like to bury the phone under the high three ',
#       'timestamps': [['dogs', 34.07, 34.55],
#        ['like', 34.55, 34.94],
#        ['to', 34.94, 35.11],
#        ['bury', 35.11, 35.55],
#        ['the', 35.55, 35.7],
#        ['phone', 35.7, 36.22],
#        ['under', 36.3, 36.65],
#        ['the', 36.65, 36.79],
# ...
#        ['hide', 105.94, 106.43],
#        ['dark', 106.43, 106.91],
#        ['gold', 106.94, 107.49]],
#       'confidence': 0.83}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'teachers like to see the cash ',
#       'timestamps': [['teachers', 108.59, 109.17],
#        ['like', 109.17, 109.53],
#        ['to', 109.53, 109.68],
#        ['see', 109.68, 110.07],
#        ['the', 110.07, 110.27],
#        ['cash', 110.27, 110.81]],
#       'confidence': 0.89}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'teachers like to see the cat ',
#       'timestamps': [['teachers', 112.08, 112.65],
#        ['like', 112.65, 112.92],
#        ['to', 112.92, 113.07],
#        ['see', 113.07, 113.34],
#        ['the', 113.34, 113.49],
#        ['cat', 113.49, 114]],
#       'confidence': 0.87}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'boys often colour cards ',
#       'timestamps': [['boys', 115.25, 115.8],
#        ['often', 115.84, 116.35],
#        ['colour', 116.38, 116.83],
#        ['cards', 116.83, 117.81]],
#       'confidence': 0.98}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'boys often colour cards ',
#       'timestamps': [['boys', 118.83, 119.19],
#        ['often', 119.27, 119.66],
#        ['colour', 119.66, 120.07],
#        ['cards', 120.07, 120.9]],
#       'confidence': 0.92}]},
#    {'final': True,
#     'alternatives': [{'transcript': "Curzon's often cook beings ",
#       'timestamps': [["Curzon's", 122.44, 123.11],
#        ['often', 123.11, 123.68],
#        ['cook', 123.71, 124.14],
#        ['beings', 124.18, 125.03]],
#       'confidence': 0.81}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'cousins often cook things ',
#       'timestamps': [['cousins', 126.16, 126.89],
#        ['often', 126.92, 127.35],
#        ['cook', 127.35, 127.78],
#        ['things', 127.81, 128.55]],
#       'confidence': 0.72}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'boys often cards cards ',
#       'timestamps': [['boys', 129.53, 130.05],
#        ['often', 130.09, 130.59],
#        ['cards', 130.59, 131.05],
#        ['cards', 131.05, 132.01]],
#       'confidence': 0.88}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'boys often cut cards ',
#       'timestamps': [['boys', 133.12, 133.6],
#        ['often', 133.63, 134.14],
#        ['cut', 134.14, 134.53],
#        ['cards', 134.6, 135.39]],
#       'confidence': 0.94}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'girls often cards ',
#       'timestamps': [['girls', 137.19, 137.69],
#        ['often', 137.69, 138.2],
#        ['cards', 138.68, 139.49]],
#       'confidence': 0.94}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'girls often cut cards ',
#       'timestamps': [['girls', 140.8, 141.26],
#        ['often', 141.29, 141.82],
#        ['cut', 142.09, 142.56],
#        ['cards', 142.59, 143.29]],
#       'confidence': 0.95}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'downs often hide pictures ',
#       'timestamps': [['downs', 144.35, 144.84],
#        ['often', 144.84, 145.31],
#        ['hide', 145.31, 145.85],
#        ['pictures', 145.85, 146.74]],
#       'confidence': 0.85}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'girls often hide pictures ',
#       'timestamps': [['girls', 148.4, 148.84],
#        ['often', 148.87, 149.29],
#        ['hide', 149.29, 149.71],
#        ['pictures', 149.71, 150.63]],
#       'confidence': 0.93}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'girls often cook carrots ',
#       'timestamps': [['girls', 151.96, 152.53],
#        ['often', 152.57, 153.08],
#        ['cook', 153.08, 153.57],
#        ['carrots', 153.61, 154.4]],
#       'confidence': 0.98}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'girls often cooked carrots ',
#       'timestamps': [['girls', 155.65, 156.1],
#        ['often', 156.13, 156.51],
#        ['cooked', 156.51, 156.95],
#        ['carrots', 156.98, 157.62]],
#       'confidence': 0.8}]},
#    {'final': True,
#     'alternatives': [{'transcript': "Carson's often cuts cards ",
#       'timestamps': [["Carson's", 159.85, 160.54],
#        ['often', 160.54, 161.06],
#        ['cuts', 161.06, 161.53],
#        ['cards', 161.53, 162.35]],
#       'confidence': 0.68}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'cousins often cut cards ',
#       'timestamps': [['cousins', 163.6, 164.23],
#        ['often', 164.26, 164.73],
#        ['cut', 164.73, 165.17],
#        ['cards', 165.2, 165.91]],
#       'confidence': 0.96}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'boys often hide gold ',
#       'timestamps': [['boys', 166.88, 167.41],
#        ['often', 167.45, 167.88],
#        ['hide', 167.88, 168.49],
#        ['gold', 168.52, 169.25]],
#       'confidence': 0.94}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'boys often hide gold ',
#       'timestamps': [['boys', 170.18, 170.6],
#        ['often', 170.63, 171],
#        ['hide', 171, 171.48],
#        ['gold', 171.48, 172.04]],
#       'confidence': 0.87}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'go for ',
#       'timestamps': [['go', 173.52, 173.67], ['for', 173.67, 173.92]],
#       'confidence': 0.38}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'girls often cuts peppers ',
#       'timestamps': [['girls', 174.89, 175.44],
#        ['often', 175.48, 175.94],
#        ['cuts', 175.94, 176.41],
#        ['peppers', 176.41, 177.28]],
#       'confidence': 0.82}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'girls often cut peppers ',
#       'timestamps': [['girls', 178.32, 178.79],
#        ['often', 178.82, 179.22],
#        ['cut', 179.22, 179.65],
#        ['peppers', 179.68, 180.44]],
#       'confidence': 0.73}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'girls often hide gold ',
#       'timestamps': [['girls', 185.58, 185.99],
#        ['often', 186.02, 186.36],
#        ['hide', 186.36, 186.78],
#        ['gold', 186.78, 187.34]],
#       'confidence': 0.78}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'husbands often hide gold ',
#       'timestamps': [['husbands', 189.23, 189.85],
#        ['often', 189.85, 190.31],
#        ['hide', 190.31, 190.89],
#        ['gold', 190.92, 191.6]],
#       'confidence': 0.88}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'cousins often hide gold ',
#       'timestamps': [['cousins', 192.65, 193.27],
#        ['often', 193.27, 193.68],
#        ['hide', 193.68, 194.21],
#        ['gold', 194.21, 194.8]],
#       'confidence': 0.85}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'girls often cook beings ',
#       'timestamps': [['girls', 196.08, 196.61],
#        ['often', 196.65, 197.12],
#        ['cook', 197.12, 197.6],
#        ['beings', 197.63, 198.48]],
#       'confidence': 0.99}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'girls often cook things ',
#       'timestamps': [['girls', 199.43, 199.87],
#        ['often', 199.9, 200.29],
#        ['cook', 200.29, 200.61],
#        ['things', 200.61, 201.31]],
#       'confidence': 0.94}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'boys like to follow the cat in the big backyard ',
#       'timestamps': [['boys', 202.42, 202.86],
#        ['like', 202.86, 203.25],
#        ['to', 203.25, 203.39],
#        ['follow', 203.39, 203.85],
#        ['the', 203.85, 204.01],
#        ['cat', 204.01, 204.43],
#        ['in', 204.47, 204.71],
#        ['the', 204.71, 204.84],
#        ['big', 204.84, 205.22],
#        ['backyard', 205.22, 206.28]],
#       'confidence': 0.83}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'girls boys like to follow the cat into the big backyard ',
#       'timestamps': [['girls', 207.31, 207.93],
#        ['boys', 208.28, 208.75],
#        ['like', 208.75, 209.06],
#        ['to', 209.06, 209.51],
#        ['follow', 209.56, 209.95],
#        ['the', 209.95, 210.12],
#        ['cat', 210.12, 210.42],
#        ['into', 210.45, 210.75],
#        ['the', 210.75, 210.87],
#        ['big', 210.87, 211.11],
#        ['backyard', 211.11, 211.8]],
#       'confidence': 0.9}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'boys like to follow the cat in the yard ',
#       'timestamps': [['boys', 213.26, 213.71],
#        ['like', 213.71, 214.09],
#        ['to', 214.09, 214.25],
#        ['follow', 214.25, 214.7],
#        ['the', 214.7, 214.87],
#        ['cat', 214.87, 215.32],
#        ['in', 215.37, 215.67],
#        ['the', 215.67, 215.85],
#        ['yard', 215.85, 216.61]],
#       'confidence': 0.91}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'boys like to follow the cat in the yard ',
#       'timestamps': [['boys', 217.51, 217.9],
#        ['like', 217.9, 218.18],
#        ['to', 218.18, 218.31],
#        ['follow', 218.31, 218.76],
#        ['the', 218.76, 218.93],
#        ['cat', 218.93, 219.27],
#        ['in', 219.3, 219.51],
#        ['the', 219.51, 219.63],
#        ['yard', 219.63, 220.15]],
#       'confidence': 0.93}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'boys always carry that came ',
#       'timestamps': [['boys', 221.79, 222.3],
#        ['always', 222.33, 222.83],
#        ['carry', 222.83, 223.23],
#        ['that', 223.23, 223.4],
#        ['came', 223.4, 223.9]],
#       'confidence': 0.89}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'the boys always carried the cake ',
#       'timestamps': [['the', 224.71, 224.79],
#        ['boys', 225.28, 225.72],
#        ['always', 225.72, 226.11],
#        ['carried', 226.11, 226.52],
#        ['the', 226.52, 226.62],
#        ['cake', 226.62, 227.22]],
#       'confidence': 0.8}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'boys always carried the cake from the shop ',
#       'timestamps': [['boys', 228.54, 229],
#        ['always', 229, 229.58],
#        ['carried', 229.58, 230.06],
#        ['the', 230.06, 230.18],
#        ['cake', 230.18, 230.58],
#        ['from', 230.58, 231.06],
#        ['the', 231.06, 231.16],
#        ['shop', 231.16, 231.87]],
#       'confidence': 0.88}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'boys always carried the cake from the shop ',
#       'timestamps': [['boys', 232.97, 233.49],
#        ['always', 233.52, 233.91],
#        ['carried', 233.91, 234.34],
#        ['the', 234.34, 234.46],
#        ['cake', 234.46, 234.8],
#        ['from', 234.8, 235.15],
#        ['the', 235.15, 235.25],
#        ['shop', 235.25, 235.83]],
#       'confidence': 0.89}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'which is always by the cash ',
#       'timestamps': [['which', 237.44, 237.6],
#        ['is', 237.6, 237.78],
#        ['always', 237.78, 238.33],
#        ['by', 238.33, 238.62],
#        ['the', 238.62, 238.79],
#        ['cash', 238.79, 239.3]],
#       'confidence': 0.71}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'teachers always buy the cake ',
#       'timestamps': [['teachers', 240.52, 241.1],
#        ['always', 241.1, 241.48],
#        ['buy', 241.48, 241.73],
#        ['the', 241.73, 241.9],
#        ['cake', 241.9, 242.51]],
#       'confidence': 0.94}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'just like to see the cat in the yard ',
#       'timestamps': [['just', 243.81, 244.2],
#        ['like', 244.2, 244.52],
#        ['to', 244.52, 244.68],
#        ['see', 244.68, 245.08],
#        ['the', 245.08, 245.27],
#        ['cat', 245.27, 245.7],
#        ['in', 245.73, 245.99],
#        ['the', 245.99, 246.14],
#        ['yard', 246.14, 246.83]],
#       'confidence': 0.83}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'teachers like to see the cat in the yard ',
#       'timestamps': [['teachers', 247.75, 248.3],
#        ['like', 248.3, 248.53],
#        ['to', 248.53, 248.68],
#        ['see', 248.68, 248.9],
#        ['the', 248.9, 249.04],
#        ['cat', 249.04, 249.38],
#        ['in', 249.42, 249.6],
#        ['the', 249.6, 249.73],
#        ['yard', 249.73, 250.25]],
#       'confidence': 0.9}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'teachers like to see the cat in the big backyard ',
#       'timestamps': [['teachers', 251.57, 252.17],
#        ['like', 252.17, 252.53],
#        ['to', 252.53, 252.68],
#        ['see', 252.68, 253.08],
#        ['the', 253.08, 253.23],
#        ['cat', 253.23, 253.69],
#        ['in', 253.72, 253.94],
#        ['the', 253.94, 254.06],
#        ['big', 254.06, 254.39],
#        ['backyard', 254.39, 255.48]],
#       'confidence': 0.83}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'teachers like to see the cat and the big backyard ',
#       'timestamps': [['teachers', 256.49, 257.04],
#        ['like', 257.04, 257.27],
#        ['to', 257.27, 257.42],
#        ['see', 257.42, 257.64],
#        ['the', 257.64, 257.78],
#        ['cat', 257.78, 258.1],
#        ['and', 258.1, 258.22],
#        ['the', 258.22, 258.32],
#        ['big', 258.32, 258.6],
#        ['backyard', 258.6, 259.42]],
#       'confidence': 0.84}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'teachers always buy the cake from the corner shop ',
#       'timestamps': [['teachers', 260.85, 261.51],
#        ['always', 261.51, 262.1],
#        ['buy', 262.1, 262.39],
#        ['the', 262.39, 262.58],
#        ['cake', 262.58, 263.01],
#        ['from', 263.01, 263.54],
#        ['the', 263.54, 263.68],
#        ['corner', 263.68, 264.14],
#        ['shop', 264.14, 264.88]],
#       'confidence': 0.99}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'teachers always buy the cake from the corner shop ',
#       'timestamps': [['teachers', 265.81, 266.39],
#        ['always', 266.39, 266.78],
#        ['buy', 266.78, 267],
#        ['the', 267, 267.17],
#        ['cake', 267.17, 267.54],
#        ['from', 267.54, 267.85],
#        ['the', 267.85, 267.96],
#        ['corner', 267.96, 268.36],
#        ['shop', 268.36, 268.88]],
#       'confidence': 0.99}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'teachers always buy the cake from the shop ',
#       'timestamps': [['teachers', 270.14, 270.7],
#        ['always', 270.7, 271.26],
#        ['buy', 271.26, 271.55],
#        ['the', 271.55, 271.76],
#        ['cake', 271.76, 272.17],
#        ['from', 272.17, 272.61],
#        ['the', 272.61, 272.73],
#        ['shop', 272.73, 273.48]],
#       'confidence': 0.98}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'teachers always buy the cake from the shop ',
#       'timestamps': [['teachers', 274.5, 275.03],
#        ['always', 275.03, 275.4],
#        ['buy', 275.4, 275.61],
#        ['the', 275.61, 275.79],
#        ['cake', 275.79, 276.13],
#        ['from', 276.13, 276.43],
#        ['the', 276.43, 276.52],
#        ['shop', 276.52, 277.01]],
#       'confidence': 0.98}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'boys always carried the cake from the corner shop ',
#       'timestamps': [['boys', 278.73, 279.2],
#        ['always', 279.2, 279.74],
#        ['carried', 279.74, 280.19],
#        ['the', 280.19, 280.29],
#        ['cake', 280.29, 280.69],
#        ['from', 280.69, 281.2],
#        ['the', 281.2, 281.33],
#        ['corner', 281.33, 281.8],
#        ['shop', 281.8, 282.55]],
#       'confidence': 0.93}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'boys always carried the cake from the corner shop ',
#       'timestamps': [['boys', 283.54, 284.07],
#        ['always', 284.1, 284.5],
#        ['carried', 284.5, 284.93],
#        ['the', 284.93, 285.02],
#        ['cake', 285.02, 285.38],
#        ['from', 285.38, 285.69],
#        ['the', 285.69, 285.79],
#        ['corner', 285.79, 286.18],
#        ['shop', 286.18, 286.71]],
#       'confidence': 0.9}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'please like to follow the cash ',
#       'timestamps': [['please', 287.73, 288.18],
#        ['like', 288.18, 288.56],
#        ['to', 288.56, 288.71],
#        ['follow', 288.71, 289.12],
#        ['the', 289.12, 289.29],
#        ['cash', 289.29, 289.78]],
#       'confidence': 0.8}]},
#    {'final': True,
#     'alternatives': [{'transcript': 'boys like to follow the cat ',
#       'timestamps': [['boys', 290.98, 291.34],
#        ['like', 291.34, 291.6],
#        ['to', 291.6, 291.73],
#        ['follow', 291.73, 292.09],
#        ['the', 292.09, 292.27],
#        ['cat', 292.27, 292.61]],
#       'confidence': 0.85}]}]}]
